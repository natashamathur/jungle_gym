# %%
import pandas as pd
import jellyfish as jf

# %%
rs = pd.read_table('SF-Rest-SmallSample.tsv', header=0)

# %%
rs.shape
# Out:
# (50630, 15)

# %%
def na_cols(df):
    '''
    Produces a list of columns in the data frame that have N/A values.
    
    Input:
        df (data frame): data frame of interest
        
    Output:
        list of columns that contain N/A's
    '''
    
    return list(df.loc[:, df.isna().any()].columns)

def isNaN(x):
    return x != x

# %%
for c in na_cols(rs):
    print(c, type(rs[c][0]))
# Out:
# business_postal_code <class 'str'>
# business_latitude <class 'numpy.float64'>
# business_longitude <class 'numpy.float64'>
# business_phone_number <class 'numpy.float64'>
# inspection_score <class 'numpy.float64'>
# violation_id <class 'str'>
# violation_description <class 'str'>
# risk_category <class 'str'>

# %%
rs.business_address = rs.business_address.str.lower()
rs.business_name = rs.business_name.str.lower()

# %%
len(rs.business_address.unique())
# Out:
# 5409

# %%
rs.style
rs.head(50)
# Out:
#                              business_name           business_address  \
# 0          dar bar pakistani/indian cusine               1412 polk st
# 1                dragon city bakery & cafe            2367 mission st
# 2                                  deli 23               2449 23rd st
# 3                 l'acajou bakery and cafe         498 09th st ste. c
# 4                          sweetheart cafe              909 grant ave
# 5                        cafe new honolulu            888 stockton st
# 6                      aux delices vietnam               2327 polk st
# 7                              cafe picaro               3120 16th st
# 8                              jelly donut               3198 24th st
# 9                limon peruvian rotisserie    1001 south van ness ave
# 10                          domino's #7764               876 geary st
# 11                               don pablo               off the grid
# ...

# %%
small = rs.head(5000)

# %%
#small.sort_values(by=['business_name'])
small[isNaN(small['business_postal_code']) ]
# Out:
#                              business_name            business_address  \
# 11                               don pablo                off the grid
# 29                    sam's chowder mobile            golden gate park
# 105                     the flying falafel              1051 market st
# 320                             montesacro            510 stevenson st
# 376                     the flying falafel              1051 market st
# 407                                j-shack                off the grid
# 421                                j-shack                off the grid
# 461                   sam's chowder mobile            golden gate park
# 512                      joe's coffee shop             6134 geary blvd
# 518                      joe's coffee shop             6134 geary blvd
# 600                          el gallo giro                3055 23rd st
# 670                                    dum                off the grid
# ...

# %%
small[small['business_address'] == 'church st']
# Out:
#       business_name business_address  business_city business_state  \
# 85    burgermeister        church st  San Francisco             CA
# 419   burgermeister        church st  San Francisco             CA
# 798   burgermeister        church st  San Francisco             CA
# 2396  burgermeister        church st  San Francisco             CA
# 2520  burgermeister        church st  San Francisco             CA
#
#      business_postal_code  business_latitude  business_longitude  \
# 85                  94114          37.768776         -122.429095
# 419                 94114          37.768776         -122.429095
# 798                 94114          37.768776         -122.429095
# 2396                94114          37.768776         -122.429095
# 2520                94114          37.768776         -122.429095
#
#       business_phone_number  inspection_id inspection_date  inspection_score  \
# 85             1.415543e+10  2627_20170105      2017-01-05              86.0
# ...

# %%
def get_street(address):
    endings = ['st', 'ave', 'st.', 'ste. c', 'pl', 'plaza']
    # remove street type abbreviations
    street = ' '.join(i for i in address.split() if i not in endings)
    # remove building numbers
    if len(street.split()) > 1:
        street=street.split(" ",1)[1]
    # remove apartment #
    if len(street.split()) > 1:
        street = street.split('#', 1)[0]
    street = street.strip(" ")

    return street

# %%
get_street('3174 16th st')
# Out:
# '16th'

# %% [raw]
# small['street'] = small['business_address'].apply(lambda x: get_street(x))

# %%
small.columns
# Out:
# Index(['business_name', 'business_address', 'business_city', 'business_state',
#        'business_postal_code', 'business_latitude', 'business_longitude',
#        'business_phone_number', 'inspection_id', 'inspection_date',
#        'inspection_score', 'inspection_type', 'violation_id',
#        'violation_description', 'risk_category'],
#       dtype='object')

# %%
# dictionary of unique instances of restaurants 

def get_dict(df):
    d = {}
    for idx,r in df.iterrows():
        d[r.business_name] = {'address': r.business_address, 
                               'postal_code': r.business_postal_code, 
                               'phone_number':r.business_phone_number}
    return d

# %%
'wiilie mays' == 'willie mays'
small.street.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-3779923c736d> in <module>()
#       1 'wiilie mays' == 'willie mays'
# ----> 2 small.street.unique()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'street'

# %%
rd = get_dict(small)
len(rd)
# Out:
# 942

# %%
def isNaN(x):
    return x != x

# %%
# s = 0
# restaurant .75, address .80, s = 52
# restaurant .80, address .80, s = 20
# restaurant .80, address .80, postal code .80, s = 20
# n = 2000, restaurant 0.80, address .80, postal code 0.9, s = 286
# n = 2000, restaurant 0.80, address .90, postal code 0.9, s = 176

def run_loop_dict(rd, sc):
    for i in rd:
        for j in rd:
            ii, jj = str(i).strip('restaurant'), str(j).strip('restaurant')
            try:
                if i!=j and jf.jaro_distance(ii, jj) > 0.80:
                    if jf.jaro_winkler(rd[i]['address'], rd[j]['address']) > 0.9:
                        if jf.jaro_winkler(rd[i]['postal_code'], rd[j]['postal_code']) > 0.9:
                            if i not in sc.keys() and j not in sc.keys():
                                sc[i] = j

            except Exception as ex:
                print("Exception", ex)
    return(sc)

# %%
def get_jw(df, i, j):
    
    if i == j:
        return False
    
    bni, bnj = df.iloc[i]['business_name'].strip('restaurant'), df.iloc[j]['business_name'].strip('restaurant')
    r = jf.jaro_winkler(bni, bnj)  
    a = jf.jaro_winkler(df.iloc[i]["business_address"], df.iloc[j]["business_address"])
    
    if r > 0.8 and a > 0.9:
        return True
    
    return False

# %%
def run_loop_df(df):
    for i in range(len(df)):
        for j in range(len(df)):
            if get_jw(df, i, j):
                   print("similar")
                   print(df.iloc[i], df.iloc[j])

# %%
def block_on_postal_code(df):
    pcs = (df.business_postal_code.unique())
    for pc in pcs:
        pc_df = df[df['business_postal_code'] == pc]
        s = run_loop_df(df)

# %%
def block_on_postal_code_dict(df):
    pcs = (df.business_postal_code.unique())
    sc = {}
    for pc in pcs:
        print(pc)
        pc_df = df[df['business_postal_code'] == pc]
        dic = get_dict(pc_df)
        sc = run_loop_dict(dic, sc)
    return sc

# %%
sc = block_on_postal_code_dict(small)
# Out:
# 94109
# 94110
# 94103
# 94108
# nan
# 94107
# 94134
# 94114
# 94118
# 94121
# 94111
# 94122
# 94133
# 94117
# 94104
# 94123
# 94102
# 94105
# 94112
# 94115
# 94143
# 94124
# 94132
# 94127
# 94131
# 94130
# 94116
# 94158
# 94602

# %%
sc
# Out:
# {'at&t - ghirardelli chocolate co. (view level) [147802]': 'at&t - ghirardelli chocolate co. (club level) [147802]',
#  'at&t park - coffee and ice cream (5a+5b)': 'at&t park - coffee and ice cream (4a+4b)',
#  'corridor': 'corridor cafe',
#  'courtyard by marriott-coffee shop': 'courtyard by marriott-staff kitchen',
#  'courtyard by marriott-staff kitchen': 'courtyard by marriott-restaurant',
#  'moscone convention center - stand #3': 'moscone convention center - stand #2',
#  'mv pisces': 'mv taurus',
#  'sf bay club -  court commisary': 'sf bay club - court cafe'}

# %%
# Out:
# 0.8257575757575758
